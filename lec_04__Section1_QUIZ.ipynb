# %% [markdown]
# ### Section 1 - FINAL QUIZ
#
# **1. What will the following code output?**
# ```python
# x = 4
# y = 5
# print(x * y if x < y else y - x)
# ```
# - A) 20
# - B) 1
# - C) 9
# - D) Error
#
# **2. Which of the following is a mutable data type in Python?**
# - A) `tuple`
# - B) `str`
# - C) `list`
# - D) `int`
#
# **3. What is the output of the following code?**
# ```python
# a = [1, 2, 3]
# print(a[-1])
# ```
# - A) 1
# - B) 3
# - C) -1
# - D) Error
#
# **4. How do you get all keys from a dictionary `d`?**
# - A) `d.get_keys()`
# - B) `d.keys`
# - C) `d.keys()`
# - D) `list(d)`
#
# **5. Which keyword is used to create a function in Python?**
# - A) `func`
# - B) `def`
# - C) `define`
# - D) `function`
#
# **6. What will this code output?**
# ```python
# x = 10
# if x % 2 == 0:
#     print("Even")
# else:
#     print("Odd")
# ```
# - A) Even
# - B) Odd
# - C) 10
# - D) Error
#
# **7. What does `range(2, 10, 2)` return?**
# - A) [2, 4, 6, 8]
# - B) [2, 3, 4, 5, 6, 7, 8, 9]
# - C) [2, 10]
# - D) [2, 6, 10]
#
# **8. What is the correct syntax to define a class?**
# - A) `define MyClass:`
# - B) `class MyClass:`
# - C) `class = MyClass()`
# - D) `def class MyClass():`
#
# **9. Which of the following creates an empty list?**
# - A) `[]`
# - B) `{}`
# - C) `list()`
# - D) Both A and C
#
# **10. What will be printed?**
# ```python
# a = {"x": 1}
# a["y"] = 2
# print(len(a))
# ```
# - A) 1
# - B) 2
# - C) 3
# - D) Error
#
# **11. What will this function do?**
# ```python
# def sum_list(nums):
#     return sum(nums)
# ```
# - A) It counts the elements
# - B) It returns their sum
# - C) It returns their average
# - D) It multiplies all numbers
#
# **12. What is the output of this code?**
# ```python
# def say_hello(name="World"):
#     print(f"Hello, {name}!")
# say_hello("Python")
# ```
# - A) Hello, name
# - B) Hello, Python
# - C) Hello, World
# - D) Error
#
# **13. What is the difference between `is` and `==` in Python?**
# - A) No difference
# - B) `is` compares identity, `==` compares value
# - C) `is` compares value, `==` compares identity
# - D) Both compare memory addresses
#
# **14. What will this loop print?**
# ```python
# for i in range(1, 4):
#     print(i * "*")
# ```
# - A) *
# - B) 1 2 3
# - C) * ** ***
# - D) *** ** *
#
# **15. What is the output of the following code?**
# ```python
# a = [1, 2, 3]
# b = a
# b.append(4)
# print(a)
# ```
# - A) [1, 2, 3]
# - B) [1, 2, 3, 4]
# - C) [4]
# - D) Error
#
# **16. What will this print?**
# ```python
# x = {"a": 1, "b": 2}
# print(x.get("c", 3))
# ```
# - A) None
# - B) "c"
# - C) 3
# - D) Error
#
# **17. Complete the function to return the max of two numbers:**
# ```python
# def max_num(a, b):
#     return _________
# ```
# - A) a if a > b else b
# - B) max(a, b, c)
# - C) abs(a - b)
# - D) min(a, b)
#
# **18. What does this class do?**
# ```python
# class Counter:
#     def __init__(self):
#         self.count = 0
#     def increment(self):
#         self.count += 1
# ```
# - A) Adds two numbers
# - B) Counts how many times `increment()` is called
# - C) Counts backwards
# - D) Resets count
#
# **19. What is the output?**
# ```python
# def func(a, b=2):
#     return a + b
# print(func(3))
# ```
# - A) 5
# - B) 6
# - C) 3
# - D) Error
#
# **20. Which of the following are loop types in Python?**
# - A) `for`, `while`, `do-while`
# - B) `loop`, `iterate`, `check`
# - C) `for`, `while`
# - D) `foreach`, `until`, `loop`
