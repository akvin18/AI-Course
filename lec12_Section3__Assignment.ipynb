# %% [markdown]
# ### Section 3 - Final Assignments : Derivatives, Partial Derivatives & Matrices (No Libraries, All Code)
#
# In this assignment, you will implement simple programs to explore the ideas of derivatives, partial derivatives, and matrices — using only basic Python.
#
# ---
#
# **Step 1: Estimate a derivative using Python**
# 💡 A derivative shows how fast a function changes at a point.
#
# 1. Define a function `f(x)` that returns `x * x`
# 2. Define another function `approx_derivative(f, x)` that returns `(f(x + 0.001) - f(x)) / 0.001`
# 3. Call `approx_derivative(f, 2)` and print the result
#
# ---
#
# **Step 2: Estimate a partial derivative by fixing one variable**
# 💡 A partial derivative changes just one variable and keeps the other constant.
#
# 1. Define a function `f(x, y)` that returns `x * x + y * y`
# 2. Write `partial_x(f, x, y)` that returns `(f(x + 0.001, y) - f(x, y)) / 0.001`
# 3. Write `partial_y(f, x, y)` that returns `(f(x, y + 0.001) - f(x, y)) / 0.001`
# 4. Call both with `x = 2`, `y = 3` and print the results
#
# ---
#
# **Step 3: Add two matrices (as lists of lists)**
# 💡 A matrix is a list of lists. To add two matrices, add the matching elements.
#
# 1. Define two 2×2 matrices:
# ```python
# A = [[1, 2], [3, 4]]
# B = [[5, 6], [7, 8]]
# ```
# 2. Write a function `add_matrices(A, B)` that returns a new matrix with the sums
# 3. Call the function and print the result
#
# ---
#
# **Step 4: Transpose a matrix (flip rows and columns)**
# 💡 Transpose means converting rows into columns.
#
# 1. Write a function `transpose(matrix)` that returns the transposed version
# 2. Try it with matrix `A` from above
# 3. Print the result
#
# 📌 Tip: For a 2x2 matrix, `transpose([[a, b], [c, d]])` should return `[[a, c], [b, d]]`
#
# ---
#
# **Step 5: Multiply two 2×2 matrices (manually)**
# 💡 Matrix multiplication is more than just element-by-element — it combines rows and columns.
#
# 1. Write a function `multiply_matrices(A, B)` that returns the product of two 2x2 matrices
#    - Use the rule:
#      `result[0][0] = A[0][0]*B[0][0] + A[0][1]*B[1][0]` and so on
# 2. Use the same `A` and `B` from above
# 3. Print the result
