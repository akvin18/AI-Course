# %% [markdown]
# ### Section2 - Final Quiz: Probability, Random Variables & Linear Functions
#
# **1. What is the probability of getting a 4 when rolling a fair six-sided die?**
# - A) 1/4
# - B) 1/5
# - C) 1/6
# - D) 1/3
#
# **2. A coin is flipped twice. What is the probability of getting exactly one head?**
# - A) 1/4
# - B) 1/2
# - C) 1/3
# - D) 3/4
#
# **3. Which of the following best describes a discrete random variable?**
# - A) Can take any value in an interval
# - B) Represents a fixed outcome
# - C) Takes on countable values only
# - D) Is always a decimal
#
# **4. The expected value of a random variable is:**
# - A) The highest value it can take
# - B) The most frequent value
# - C) The average outcome weighted by probability
# - D) The variance of its distribution
#
# **5. A biased coin shows heads with probability 0.7. What’s the probability of getting tails?**
# - A) 0.3
# - B) 0.7
# - C) 1.3
# - D) 0.5
#
# **6. Which of the following is not a valid probability?**
# - A) 0.25
# - B) 1.0
# - C) -0.1
# - D) 0
#
# **7. A bag has 5 red and 3 blue balls. What is the probability of drawing a red ball?**
# - A) 3/8
# - B) 5/8
# - C) 1/2
# - D) 2/5
#
# **8. If X is a discrete random variable with P(X=1)=0.2, P(X=2)=0.5, P(X=3)=0.3, what is E[X]?**
# - A) 1.5
# - B) 2.1
# - C) 2.3
# - D) 2.6
#
# **9. The variance of a random variable measures:**
# - A) Its most likely outcome
# - B) Its rate of change
# - C) Its average deviation from the mean
# - D) Its slope
#
# **10. If f(x) = 3x - 7, what is the slope?**
# - A) -7
# - B) 3
# - C) x
# - D) 0
#
# **11. What does the slope of a linear function represent?**
# - A) Vertical shift
# - B) Point of intersection
# - C) Rate of change
# - D) Total area under the curve
#
# **12. Which of the following is the graph of a linear function?**
# - A) A curve opening upward
# - B) A horizontal line
# - C) A circle
# - D) A vertical line
#
# **13. What is the slope between the points (1, 2) and (4, 8)?**
# - A) 2
# - B) 3
# - C) 4
# - D) 6
#
# **14. A line has a slope of 0. What kind of line is it?**
# - A) Vertical
# - B) Diagonal
# - C) Horizontal
# - D) Non-linear
#
# **15. If two events A and B are independent, then P(A ∩ B) equals:**
# - A) P(A) + P(B)
# - B) P(A) * P(B)
# - C) P(A) / P(B)
# - D) min(P(A), P(B))
#
# **16. The function f(x) = -5x + 12 is:**
# - A) Linear, increasing
# - B) Linear, decreasing
# - C) Non-linear
# - D) Constant
#
# **17. What is the y-intercept of f(x) = 2x - 9?**
# - A) -9
# - B) 2
# - C) 0
# - D) 1
#
# **18. In a linear function, when the slope is positive:**
# - A) The function decreases left to right
# - B) The function is constant
# - C) The function increases left to right
# - D) The function is undefined
#
# **19. If P(A) = 0.4 and P(B) = 0.5 and A and B are mutually exclusive, what is P(A ∪ B)?**
# - A) 0.9
# - B) 0.2
# - C) 0.45
# - D) 1.0
#
# **20. What is the slope of a line passing through points (0, 0) and (5, 10)?**
# - A) 2
# - B) 10
# - C) 5
# - D) 0
